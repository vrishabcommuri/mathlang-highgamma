# %%
import scipy
from scipy.io import wavfile
import pathlib
import matplotlib.pyplot as plt

# %%
datadir = pathlib.Path.cwd() / "../../../data/gamma_trf/"
trialnum = 0
SINGLE_SPEAKER_STIMFOLDER = "single_speaker_stimuli"
condition = "01jamesMath"
trialnum = str(trialnum).zfill(2)

# trialprefix = ""
# if stimdir == COCKTAIL_STIMFOLDER:
#     trialprefix = condition[-2:] + "_"
#     condition = condition[:-3]

stim_file = datadir / f"stimuli/{SINGLE_SPEAKER_STIMFOLDER}/{condition}/trial{str(trialnum).zfill(2)}.wav"

x = scipy.io.wavfile.read(stim_file)[1]

# %%
plt.plot(x[1000:40000])

plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
plt.plot(x[79000:118000])

plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
79000 + (40000- 1000)
# Out:
# 118000
